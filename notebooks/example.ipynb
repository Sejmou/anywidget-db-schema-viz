# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from db_schema_viz import DBSchemaVizWidget
widget = DBSchemaVizWidget(entities={
    "Track": {
        "name": "Track",
        "attributes": [
            {"name": "track_id", "datatype": "VARCHAR", "primary_key": True},
            {"name": "release_id", "datatype": "VARCHAR", "primary_key": False,
             "foreign_key": {"entity": "Release", "attribute": "release_id"}},
            {"name": "track_title", "datatype": "VARCHAR", "primary_key": False}
        ],
    },
    "Release": {
        "name": "Release",
        "attributes": [
            {"name": "release_id", "datatype": "VARCHAR", "primary_key": True},
            {"name": "artist_id", "datatype": "VARCHAR", "primary_key": False,
             "foreign_key": {"entity": "Artist", "attribute": "artist_id"}},
            {"name": "release_title", "datatype": "VARCHAR", "primary_key": False}
        ],
    },
    "Artist": {
        "name": "Artist",
        "attributes": [
            {"name": "artist_id", "datatype": "VARCHAR", "primary_key": True},
            {"name": "artist_name", "datatype": "VARCHAR", "primary_key": False}
        ],
    },
})

widget

# %%
widget.datatype_truncate_length
# Out:
# 30
