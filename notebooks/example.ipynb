# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from db_schema_viz import DBSchemaVizWidget
widget = DBSchemaVizWidget(entities=[
  {
    "name": "artist_image_ai_detection_meta",
    "attributes": [
      {
        "name": "artist_id",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "image_url",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "subset",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "ai_score",
        "datatype": "DOUBLE",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "inference_timestamp",
        "datatype": "TIMESTAMP WITH TIME ZONE",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "label",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      }
    ]
  },
  {
    "name": "artist_release_relationships",
    "attributes": [
      {
        "name": "artist_id",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "release_id",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "relationship_type",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "artist_track_streams",
        "datatype": "UBIGINT",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "artist_feature_count",
        "datatype": "UBIGINT",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "min_artist_rank",
        "datatype": "UINTEGER",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "max_artist_rank",
        "datatype": "UINTEGER",
        "primary_key": False,
        "foreign_key": None
      }
    ]
  },
  {
    "name": "artists",
    "attributes": [
      {
        "name": "id",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "name",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "subset",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "total_release_streams",
        "datatype": "UINTEGER",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "followers",
        "datatype": "UINTEGER",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "popularity",
        "datatype": "UTINYINT",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "genres",
        "datatype": "VARCHAR[]",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "observed_at",
        "datatype": "TIMESTAMP WITH TIME ZONE",
        "primary_key": False,
        "foreign_key": None
      }
    ]
  },
  {
    "name": "cover_image_ai_detection_meta",
    "attributes": [
      {
        "name": "album_id",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "image_url",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "subset",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "ai_score",
        "datatype": "DOUBLE",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "inference_timestamp",
        "datatype": "TIMESTAMP WITH TIME ZONE",
        "primary_key": False,
        "foreign_key": None
      },
      {
        "name": "label",
        "datatype": "VARCHAR",
        "primary_key": False,
        "foreign_key": None
      }
    ]
  },
  
])

widget

# %%
widget.datatype_truncate_length
# Out:
# 30
